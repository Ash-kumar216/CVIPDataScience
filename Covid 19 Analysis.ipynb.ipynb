# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA COLLECTION

# %%
data = pd.read_csv(r"C:\Users\91944\OneDrive\Desktop\CVIP Proj\state_level_latest(5).csv")

# %%
data
# Out:
#                                        State  Confirmed  Recovered  Deaths  \
# 0                                      Total    2025409    1377384   41638
# 1                                Maharashtra     479779     316375   16792
# 2                                 Tamil Nadu     279144     221087    4571
# 3                                      Delhi     141531     127124    4059
# 4                                  Karnataka     158254      80281    2897
# 5                             Andhra Pradesh     196789     112870    1753
# 6                              Uttar Pradesh     108974      63402    1918
# 7                                    Gujarat      67811      50524    2579
# 8                                West Bengal      86754      61023    1902
# 9                                  Telangana      73050      52103     589
# 10                                 Rajasthan      48996      35131     757
# ...

# %%
data.head()
# Out:
#          State  Confirmed  Recovered  Deaths  Active    Last_Updated_Time  \
# 0        Total    2025409    1377384   41638  605933  06/08/2020 23:46:37
# 1  Maharashtra     479779     316375   16792  146305  06/08/2020 20:42:51
# 2   Tamil Nadu     279144     221087    4571   53486  06/08/2020 19:44:47
# 3        Delhi     141531     127124    4059   10348  06/08/2020 18:39:45
# 4    Karnataka     158254      80281    2897   75067  06/08/2020 21:19:51
#
#    Migrated_Other State_code  Delta_Confirmed  Delta_Recovered  Delta_Deaths  \
# 0             454         TT                0                0             0
# 1             307         MH                0                0             0
# 2               0         TN                0                0             0
# 3               0         DL                0                0             0
# 4               9         KA                0                0             0
#
#                                          State_Notes
# ...

# %%
data.tail()
# Out:
#                           State  Confirmed  Recovered  Deaths  Active  \
# 33                       Sikkim        829        353       1     475
# 34                      Mizoram        538        288       0     249
# 35  Andaman and Nicobar Islands       1123        355      16     752
# 36             State Unassigned          0          0       0       0
# 37                  Lakshadweep          0          0       0       0
#
#       Last_Updated_Time  Migrated_Other State_code  Delta_Confirmed  \
# 33  06/08/2020 23:01:46               0         SK                0
# 34  06/08/2020 17:29:49               1         MZ                0
# 35  06/08/2020 20:45:08               0         AN                0
# 36  19/07/2020 09:40:01               0         UN                0
# 37  26/03/2020 07:19:29               0         LD                0
#
#     Delta_Recovered  Delta_Deaths  \
# 33                0             0
# 34                0             0
# ...

# %%
data.describe()
# Out:
#           Confirmed     Recovered        Deaths         Active  \
# count  3.800000e+01  3.800000e+01     38.000000      38.000000
# mean   1.066005e+05  7.249389e+04   2191.473684   31891.210526
# std    3.332312e+05  2.267774e+05   7163.656211  100001.749436
# min    0.000000e+00  0.000000e+00      0.000000       0.000000
# 25%    2.106000e+03  1.194000e+03      9.250000     849.250000
# 50%    1.832350e+04  1.087350e+04    114.000000    6460.000000
# 75%    6.806375e+04  4.884800e+04    898.750000   15275.000000
# max    2.025409e+06  1.377384e+06  41638.000000  605933.000000
#
#        Migrated_Other  Delta_Confirmed  Delta_Recovered  Delta_Deaths
# count       38.000000             38.0             38.0          38.0
# mean        23.894737              0.0              0.0           0.0
# std         87.402081              0.0              0.0           0.0
# min          0.000000              0.0              0.0           0.0
# ...

# %% [markdown]
# #

# %%
data.isnull().sum()
# Out:
# State                 0
# Confirmed             0
# Recovered             0
# Deaths                0
# Active                0
# Last_Updated_Time     0
# Migrated_Other        0
# State_code            0
# Delta_Confirmed       0
# Delta_Recovered       0
# Delta_Deaths          0
# State_Notes          23
# dtype: int64

# %%
data.columns
# Out:
# Index(['State', 'Confirmed', 'Recovered', 'Deaths', 'Active',
#        'Last_Updated_Time', 'Migrated_Other', 'State_code', 'Delta_Confirmed',
#        'Delta_Recovered', 'Delta_Deaths', 'State_Notes'],
#       dtype='object')

# %% [markdown]
# # BG REPRESENTATION

# %%
data.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_99618_row0_col1, #T_99618_row0_col2, #T_99618_row0_col3, #T_99618_row0_col4, #T_99618_row0_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# ...

# %% [markdown]
# # ANALYSING DATA

# %%
data.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
sns.relplot(x="Confirmed", y="Active", data=data)

# %%
sns.relplot(x="Active", y="Confirmed", hue="Recovered", data=data)

# %%
 sns.pairplot(data)

# %%
sns.relplot(x="Confirmed",y="Recovered",kind="line", data=data)

# %%
data['Confirmed'].value_counts().plot(kind='bar', figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# # ACTIVE CASES THROUGH PIE PLOT

# %%
plt.figure(figsize=(20,10))
data['Active'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Active'>

# %% [markdown]
# # ANALYSING THROUGH DATE

# %%
df_date=data.groupby(['Last_Updated_Time']).sum().reset_index(drop=None)
# Out:
# C:\Users\91944\AppData\Local\Temp\ipykernel_17996\1033006932.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_date=data.groupby(['Last_Updated_Time']).sum().reset_index(drop=None)

# %%
df_date
# Out:
#       Last_Updated_Time  Confirmed  Recovered  Deaths  Active  Migrated_Other  \
# 0   06/08/2020 11:26:06      73050      52103     589   20358               0
# 1   06/08/2020 11:43:39       5740       3793      31    1898              18
# 2   06/08/2020 17:29:43      68148      43820     388   23939               1
# 3   06/08/2020 17:29:49        538        288       0     249               1
# 4   06/08/2020 17:53:49     108974      63402    1918   43654               0
# 5   06/08/2020 18:11:03       4621       2808      70    1743               0
# 6   06/08/2020 18:11:05       1327        777      20     529               1
# 7   06/08/2020 18:19:43      23454      15708     436    7310               0
# 8   06/08/2020 18:39:45     141531     127124    4059   10348               0
# 9   06/08/2020 18:39:49       2580        819       6    1752               3
# 10  06/08/2020 19:18:40       3217       1905       8    1304               0
# ...

# %%
df_date.columns
# Out:
# Index(['Last_Updated_Time', 'Confirmed', 'Recovered', 'Deaths', 'Active',
#        'Migrated_Other', 'Delta_Confirmed', 'Delta_Recovered', 'Delta_Deaths'],
#       dtype='object')

# %%
df_date[['Confirmed','Deaths','Recovered']].plot(kind='line')
# Out:
# <Axes: >
